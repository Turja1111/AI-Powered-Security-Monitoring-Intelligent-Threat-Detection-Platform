# %% [markdown]
# # 🧪 Feature Engineering Verification
#
# This notebook demonstrates the extraction of 26 cybersecurity features (volumes, behavioral stats, and TCP flag ratios) from raw IP network traffic logs.

# %%
import pandas as pd
import numpy as np
from data_utils import generate_synthetic_data

# Generate mock raw logs
raw_logs = generate_synthetic_data(n_samples=2000)
print(f"Loaded {len(raw_logs)} raw connection logs.")

# %%
# Demonstrating basic feature statistics
raw_logs.groupby('label')[['bytes_sent', 'bytes_received', 'packet_count', 'duration_ms']].mean()
