# %% [markdown]
# # 📊 Model Evaluation & Comparison
#
# This notebook generates classification reports, confusion matrices, ROC curves, and SHAP feature importance charts to compare model performances.

# %%
print("To generate the final model comparison tables and charts, execute:")
print("python evaluate.py")
