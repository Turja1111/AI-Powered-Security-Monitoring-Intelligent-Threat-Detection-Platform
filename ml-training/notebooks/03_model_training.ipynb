# %% [markdown]
# # 🤖 Model Training & Hyperparameter Optimization
#
# This notebook covers the local training loops for the multi-model ensemble (Isolation Forest, XGBoost, and PyTorch LSTM autoencoder) tracking parameters via MLflow.

# %%
print("To start training the models, execute the command-line scripts:")
print("python train_isolation_forest.py")
print("python train_xgboost.py")
print("python train_lstm.py")
